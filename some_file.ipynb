# %%
# below is some code with several lines
# the purpose is to have a lot of lines, so we can test commenting in pull requests on multiple lines, and accept/reject

#remove special characters and numbers
def remove_special_and_numbers(text):
    return ''.join(
        ch if ch.isalpha() or ch.isspace() else ' '
        for ch in text
    )

X_clean_html = X_clean_html.apply(remove_special_and_numbers)
